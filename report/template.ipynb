# %% [raw]
# ---
# title: "Template"
# format:
#   html:
# execute:
#   echo: false
# jupyter: python3
# ---

# %%
import psycopg2
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
ticker = "GOOGL"

# %% [markdown]
# ### Comparative Sentiment Analysis

# %%
query = """
SELECT * 
FROM public.insights;
"""

conn = psycopg2.connect(
    dbname="postgres",
    host="localhost",
    port="5432",
    user="caiogimenes",
    password="financialreport"
)

data = pd.read_sql(
    query,
    conn
)
data = data.drop_duplicates(subset=['url'])
sns.countplot(data, x='sentiment', hue='company');
